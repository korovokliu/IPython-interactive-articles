# %% [markdown]
# ## Определяем граф через словарь

# %%
G = Graph({
    0: [1, 2, 3],
    2: [3, 4, 5],
    3: [4],
    6: []
})
G.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Graphics object consisting of 15 graphics primitives

# %%
prиint(f"Вершины графа: {G.vertices()},\n\n
        Рёбра графа (начало, конец, вес): {G.edges()}")
# Out:
# Вершины графа: [0, 1, 2, 3, 4, 5, 6],
# Рёбра графа: [(0, 1, None), (0, 2, None), (0, 3, None), (2, 3, None), (2, 4, None), (2, 5, None), (3, 4, None)]

# %%
G.edges()
# Out:
# [(0, 1, None), (0, 2, None), (0, 3, None), (2, 3, None), (2, 4, None), (2, 5, None), (3, 4, None)]
