# %% [raw]
# Заглавная страница:

# %% [markdown]
# Список всех игр:
# Вектора и матрицы

# %% [raw]
# Введение
#
#
#
# Сложность: 1 курс
# Теги: python, линейная алгебра, матрицы, электроника, экономика, прикладные задачи,
# Наличие бекграунда: школьная программа, желательно, представлять, как выглядят матрицы, что такое множество, диаграммы Венна и операции со множествами. Знать, что является элементом множества, а что подмножеством
# Новые знания:
# Полный список вводящихся терминов: кортеж, декартово произведение, отношение, операция, функция (отображение), агебраическая система, полугруппа, группа, моноид, кольцо, поле, вектор, векторное пространство, модуль, рефлексивность, транзитивность, симметричность, антисимметричность, матрица, образ, прообраз, симметричная матрица, кососимметричная матрица, линейная связь, базис, транспонирование матрицы, детерминант, ранг матрицы
#
# Используемая литература:
#
#
# В этой игре ты узнаешь основы линейной алгебры, про матрицы и операции с ними.
